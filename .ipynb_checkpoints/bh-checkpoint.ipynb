# %%
import random
import algviz
# Create a visualizer object.
# The default duration of each frame of animation is 0.2 second.
# The interval between two frames of animation is 0.1 seconds.
viz = algviz.Visualizer(delay=0.1, wait=0.05)

viz.display()               # Display the firt animation frame.
# Do something...
viz.display(delay=1.0)      # Display the second animation frame.

tree_info = {
    0: [1, 2, 3],  # Node0 has child nodes: 1, 2, 3.
    1: [4, 5],      # Node1 has child nodes: 4, 5.
    2: [6]# Node2 has child node: 6.
}
nodes_label = {
    0: 'root',      # Set the display name of node0 as 'root'.
    3: 'n3'         # Set the display name of node3 as 'n3'.
}
root2 = algviz.parseTree(tree_info, nodes_label)
tree = viz.createGraph(data=root2, name="Tree")
viz.display()
for child in root2.children():
    tree.markNode(algviz.color_red, child)
    viz.display(1.0)
# Out:
# Tree:

# %%
tab = viz.createGraph(              # The table has 3 columns
    data=[root1,root2],                # The initial data in table.
    name="Binomial Heap"        # Whether to display subscripts.
)
viz.display()
print(type(root1))
root1.bind_graphs()
viz.display()
tab2 = viz.createGraph(              # The table has 3 columns
    data=[root3],                # The initial data in table.
    name="Binomial Heap 2"        # Whether to display subscripts.
)

viz.display()
# Out:
# Binomial Heap:
# <class 'algviz.tree.BinaryTreeNode'>
# Binomial Heap 2:
